# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/customer_spending_dataset.csv")

# %%
print(df)
# Out:
#    CustomerID  Age  MonthlySpend
# 0           1   22            15
# 1           2   25            20
# 2           3   24            18
# 3           4   45            80
# 4           5   50            85
# 5           6   48            78
# 6           7   30            40
# 7           8   32            42
# 8           9   29            38
# 9          10   31            45

# %%
wcss = []

for k in range (1,11):
  model = KMeans(n_clusters=k, random_state=42)
  model.fit(df)
  wcss.append(model.inertia_)

plt.plot(range(1,11),wcss,marker="o")
plt.xlabel("Number of clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3, random_state=42)
df["cluster"] = model.fit_predict(df)
print(df)

plt.scatter(df["Age"], df["MonthlySpend"],c=df["cluster"],cmap='viridis')
plt.xlabel("Age")
plt.ylabel("Monthly Spend")
plt.title("K-Means Clustering")
plt.show()
# Out:
#    CustomerID  Age  MonthlySpend  cluster
# 0           1   22            15        2
# 1           2   25            20        2
# 2           3   24            18        2
# 3           4   45            80        0
# 4           5   50            85        0
# 5           6   48            78        0
# 6           7   30            40        1
# 7           8   32            42        1
# 8           9   29            38        1
# 9          10   31            45        1

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(df,df["cluster"])
print("Silhouette Score", score)
# Out:
# Silhouette Score 0.8342808028273693
